# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
tickers = ["MSFT", "AMZN", "KO", "MA", "COST", 
           "LUV", "XOM", "PFE", "JPM", "UNH", 
           "ACN", "DIS", "GILD", "F", "TSLA"] 
ohlc = yf.download(tickers=tickers,period="max")
# Out:
# [*********************100%%**********************]  15 of 15 completed

# %%
prices = ohlc['Adj Close'].dropna()
prices.head()
# Out:
# Ticker            ACN    AMZN       COST        DIS         F       GILD  \
# Date
# 2010-06-29  29.723209  5.4305  39.997116  27.914082  5.532362  12.592292
# 2010-06-30  29.723209  5.4630  39.421917  27.222712  5.644354  12.343830
# 2010-07-01  29.438656  5.5480  39.472244  27.214071  5.918732  12.293420
# 2010-07-02  29.177193  5.4570  38.990517  27.119003  5.756341  12.556287
# 2010-07-06  29.538631  5.5030  38.825146  27.412836  5.689149  12.520281
#
# Ticker            JPM         KO       LUV         MA       MSFT       PFE  \
# Date
# 2010-06-29  25.399754  16.225098  9.850551  18.820280  17.745979  7.839474
# 2010-06-30  25.091347  16.157398  9.850551  18.499487  17.517593  7.828495
# 2010-07-01  24.761921  16.128382  9.744154  18.807535  17.631784  7.812029
# 2010-07-02  24.590343  16.134823  9.531358  18.814026  17.715532  7.762618
# 2010-07-06  24.933500  16.257334  9.424960  18.559801  18.134247  7.844968
#
# Ticker          TSLA        UNH        XOM
# Date
# ...

# %%
prices[prices.index > '2017-01-01'].plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
import pypfopt
pypfopt.__version__
# Out:
# '1.5.5'

# %%
from pypfopt import risk_models
from pypfopt import plotting
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\versu\anaconda3\envs\Thesis\lib\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File c:\Users\versu\anaconda3\envs\Thesis\lib\site-packages\matplotlib\__init__.py:883, in _rc_params_in_file(fname, transform, fail_on_error)
#     882 rc_temp = {}
# --> 883 with _open_file_or_url(fname) as fd:
#     884     try:
#
# File c:\Users\versu\anaconda3\envs\Thesis\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#
# File c:\Users\versu\anaconda3\envs\Thesis\lib\site-packages\matplotlib\__init__.py:860, in _open_file_or_url(fname)
#     859 fname = os.path.expanduser(fname)
# ...

# %%
import numpy as np
import pandas as pd
import yfinance as yf

ohlc = yf.download(tickers=['AMZN','TSLA'],period='max')
prices = ohlc['Adj Close'].dropna()
prices.tail()
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Ticker            AMZN        TSLA
# Date
# 2024-09-09  175.399994  216.270004
# 2024-09-10  179.550003  226.169998
# 2024-09-11  184.520004  228.130005
# 2024-09-12  187.000000  229.809998
# 2024-09-13  186.490005  230.289993

# %%
prices.plot(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
a = np.array([1,5,1,9,78,1,8,9,1])
a[::2]
a.sum()
a.cumsum()
# Out:
# array([  1,   6,   7,  16,  94,  95, 103, 112, 113])
